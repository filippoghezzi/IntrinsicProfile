# %%
import pandas as pd
import numpy as np
import pyabf
import matplotlib.pyplot as plt
from scipy import stats, signal, optimize

# %%
    def Analyse_IntrinsicProfile(V, I, t, sr, plotting):

        #Start-end current command
        dI = np.insert(np.diff(I),0,0)
        I_peaks,_ = signal.find_peaks(dI,height=10)
        if np.shape(I_peaks)[0]:
            I_ON = np.argmax(dI)
            I_OFF = np.argmin(dI)

            if I_ON > I_OFF: #Invert ON and OFF for negative current steps
                I_OFF = np.argmax(dI)
                I_ON = np.argmin(dI)

            commandDuration=t[I_OFF]-t[I_ON]
            I_command=np.round(np.mean(I[I_ON+int(0.1*sr):I_ON+int(0.2*sr)])-np.mean(I[I_ON-int(0.2*sr):I_ON-int(0.1*sr)]))

            # Find hyperpolarization-induced voltage sag
            if I_command < 0:
                V_Ih_inst_idx = np.argmin(V[I_ON:I_OFF])+I_ON
                V_Ih_inst = V[V_Ih_inst_idx]
                V_Ih_ss = V[I_OFF]
                V_Ih = V_Ih_ss - V_Ih_inst
                
            else:
                V_Ih = np.nan
                V_Ih_ss = np.nan
            
            #Find firing frequency: number action potentials (APs)
            V_peaks, _ = signal.find_peaks(V[I_ON:I_OFF],height=-20,prominence=10)            
            AP_firingFrequency = np.shape(V_peaks)[0]/commandDuration
            
            if np.shape(V_peaks)[0] != 0:
                #Find firing frequency adaptation
                adaptationWindow = 0.1
                spikeN_i = np.count_nonzero((V_peaks)<adaptationWindow *sr)
                spikeN_f = np.count_nonzero(((V_peaks)>(commandDuration-adaptationWindow)*sr) & ((V_peaks)<commandDuration*sr))
                if spikeN_i != 0:
                    AP_adaptation = (spikeN_i-spikeN_f)/spikeN_i*100
                else:
                    AP_adaptation  = np.nan

            else:
                AP_adaptation  = np.nan
        
            if np.shape(V_peaks)[0] in [1,2,3] and I_command < 200:
                V_peaks = V_peaks + I_ON
                if np.shape(V_peaks)[0] in [2,3]:
                    end_idx = (V_peaks)[1]
                else:
                    end_idx = I_OFF
                
                #Find rheobase
                rheobase = I_command
                
                AP_window = np.arange(V_peaks[0]-int(0.03*sr),end_idx)
                AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP = Analyse_Spike(V[AP_window], t[AP_window], sr, int(0.03*sr), plotting)

            else:
                rheobase = np.nan
                AP_threshold = np.nan
                AP_spikeHeight = np.nan
                AP_halfWidth = np.nan
                AP_fAHP = np.nan
        
        elif not np.shape(I_peaks)[0] and np.mean(V[int(0.5*sr):int(0.55*sr)]) > np.mean(V[int(0.45*sr):int(0.5*sr)]) + 3*np.std(V[int(0.45*sr):int(0.5*sr)]):
            
            I_ON = int(0.5*sr)
            I_OFF = int(1*sr)
            commandDuration = 0.5
            I_command = np.nan
            V_Ih = np.nan
            V_Ih_ss = np.nan
            
            #Find firing frequency: number action potentials (APs)
            V_peaks, _ = signal.find_peaks(V[I_ON:I_OFF],height=-20,prominence=10)            
            AP_firingFrequency = np.shape(V_peaks)[0]/commandDuration
            
            if np.shape(V_peaks)[0] != 0:
                #Find firing frequency adaptation
                adaptationWindow = 0.1
                spikeN_i = np.count_nonzero((V_peaks)<adaptationWindow *sr)
                spikeN_f = np.count_nonzero(((V_peaks)>(commandDuration-adaptationWindow)*sr) & ((V_peaks)<commandDuration*sr))
                if spikeN_i != 0:
                    AP_adaptation = (spikeN_i-spikeN_f)/spikeN_i*100
                else:
                    AP_adaptation  = np.nan

            else:
                AP_adaptation  = np.nan
        
            if np.shape(V_peaks)[0] in [1,2,3]:
                V_peaks = V_peaks + I_ON
                if np.shape(V_peaks)[0] in [2,3]:
                    end_idx = (V_peaks)[1]
                else:
                    end_idx = I_OFF
                
                #Find rheobase
                rheobase = I_command
                
                AP_window = np.arange(V_peaks[0]-int(0.03*sr),end_idx)
                AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP = Analyse_Spike(V[AP_window], t[AP_window], sr, int(0.03*sr), plotting)

            else:
                rheobase = np.nan
                AP_threshold = np.nan
                AP_spikeHeight = np.nan
                AP_halfWidth = np.nan
                AP_fAHP = np.nan
        
        elif not np.shape(I_peaks)[0] and np.mean(V[int(0.5*sr):int(0.55*sr)]) < np.mean(V[int(0.45*sr):int(0.5*sr)]) + 3*np.std(V[int(0.45*sr):int(0.5*sr)]):
            
            I_ON = int(0.5*sr)
            I_OFF = int(1*sr)
            commandDuration = 0.5
            I_command = np.nan
            rheobase = np.nan
            AP_threshold = np.nan
            AP_spikeHeight = np.nan
            AP_halfWidth = np.nan
            AP_fAHP = np.nan
            AP_firingFrequency = np.nan
            AP_adaptation = np.nan

            
            # Find hyperpolarization-induced voltage sag
            V_Ih_inst_idx = np.argmin(V[I_ON:I_OFF])+I_ON
            V_Ih_inst = V[V_Ih_inst_idx]
            V_Ih_ss = V[I_OFF]
            V_Ih = V_Ih_ss - V_Ih_inst
                          
            
        else:
            commandDuration = 0.5
            I_command = 0
            I_ON = int(0.5*sr)
            V_Ih = np.nan
            V_Ih_ss = np.nan
            AP_firingFrequency = np.nan
            rheobase = np.nan
            AP_threshold = np.nan
            AP_spikeHeight = np.nan
            AP_halfWidth = np.nan
            AP_fAHP = np.nan
            AP_adaptation = np.nan

        #Find resting membrane potential
        RMP = np.mean(V[0:I_ON-int(0.05*sr)])
        
        return [commandDuration,I_command,RMP,AP_firingFrequency,V_Ih,V_Ih_ss,rheobase,AP_threshold,AP_spikeHeight,AP_halfWidth,AP_fAHP,AP_adaptation]

# %%
    def Analyse_Rin(V, I, t, sr, plotting):
        #Start-end current command
        dI = np.insert(np.diff(I),0,0)
        I_peaks,_ = signal.find_peaks(dI,height=5)
        if np.shape(I_peaks)[0]:
            I_ON = np.argmax(dI)
            I_OFF = np.argmin(dI)

            if I_ON > I_OFF: #Invert ON and OFF for negative current steps
                I_OFF = np.argmax(dI)
                I_ON = np.argmin(dI)

            commandDuration=t[I_OFF]-t[I_ON]
            deltaI=np.round(np.mean(I[I_ON+int(0.01*sr):I_ON+int(0.02*sr)])-np.mean(I[I_ON-int(0.02*sr):I_ON-int(0.01*sr)]))
        
        else:
            Vf = butter_lowpass_filter(V-V[0], 200, sr, 2)
            dV = np.insert(np.diff(Vf,n=1),0,0)
            I_ON = np.argmin(dV)-100
            I_OFF = np.argmax(dV)-100
            deltaI = 10 #pA

        
        #Find input resistance (Rin) in MOhm
        deltaV = np.mean(V[I_ON-int(0.05*sr):I_ON])-np.mean(V[I_OFF-int(0.05*sr):I_OFF])  
        Rin = abs(deltaV/deltaI*1000)
        
        #Find decay time constant
        if (I_OFF-I_ON)/sr > 0.3:
            fitOFF = I_ON+int(0.2*sr)
        else:
            fitOFF = I_OFF  
        
        def mono_exp(x, a, b):
             return a * np.exp(b * x)

        xfit = t[I_ON:fitOFF]
        yfit = V[I_ON:fitOFF]-np.mean(V[fitOFF-int(0.005*sr):fitOFF])
        popt,pcov = optimize.curve_fit(mono_exp, xfit, yfit, method = 'lm', maxfev = 15000, ftol = 10**-10)
        Tau = 1/(-popt[1])     
            
        #Plot tau fitting
        if plotting:
            plt.figure()
            plt.plot(xfit, yfit, 'k', label="Data")
            plt.plot(xfit, mono_exp(xfit, *popt), 'r-', label="Fitted Curve")            
            plt.legend()
            plt.show()
            
        return Rin, Tau

# %%
    def Analyse_Baseline(V, I, t, sr, plotting):
        
        RMP = np.mean(V[0:int(0.05*sr)])
        V_peaks, _ = signal.find_peaks(V,height=-20)            
        rheobase = np.max(I)-I[0]
        
        if np.shape(V_peaks)[0]>=1:
            AP_window = np.arange(V_peaks[0]-int(0.03*sr),V_peaks[0]+int(0.1*sr))
            AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP = Analyse_Spike(V[AP_window], t[AP_window], sr, int(0.03*sr), plotting)
        elif np.shape(V_peaks)[0]==0:
            print("ERROR: no action potential detected in baseline file")
        
        return (RMP, rheobase, AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP)

# %%
    def Analyse_Spike(V, t, sr, spikeIdx, plotting):
        #Find AP threshold: first derivative method, 20 % peak velocity cut-off
        dV = np.insert(np.diff(V,n=1),0,0)
        dV_peaks, _ = signal.find_peaks(dV,height=1)
        Th_idx = np.argmin(abs(dV[:dV_peaks[0]]-dV[dV_peaks][0]*0.05))
        AP_threshold = V[Th_idx]
        
        #Find AP height
        AP_peakHeight = V[spikeIdx]
        AP_spikeHeight = AP_peakHeight-AP_threshold
        
        #Find AP half-width
        AP_halfHeigth = AP_spikeHeight/2
        Half_Start = np.argmin(abs(V[Th_idx:spikeIdx]-(AP_peakHeight-AP_halfHeigth)))+Th_idx
        Half_End = np.argmin(abs(V[spikeIdx:]-(AP_peakHeight-AP_halfHeigth)))+spikeIdx
        AP_halfWidth = t[Half_End]-t[Half_Start]

        #Find fast AHP (fAHP) amplitude
        fAHP_idx = np.argmin(V[spikeIdx:])+spikeIdx
        AP_fAHP = AP_threshold - V[fAHP_idx]
        
        #Plot AP and points of interest
        if plotting:
            plt.figure()
            plt.plot(t,V)
            plt.plot(t[spikeIdx],V[spikeIdx],'rx')
            plt.plot(t[Th_idx],V[Th_idx],'bx')
            plt.plot(t[Half_Start],V[Half_Start],'bx')
            plt.plot(t[Half_End],V[Half_End],'bx')
            plt.plot(t[fAHP_idx],V[fAHP_idx],'bx')              

        return(AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP)

# %%
    def Analyse_Neuron(neuron):
        plotting = 0
        # Initialise dataframe for single cell data 
        cols=['CommandDuration','CommandAmplitude','RMP','FiringFrequency','VoltageSag','V_Ih_SS','Rheobase','Threshold','SpikeHeight','SpikeHalfWidth','fAHPamplitude','Adaptation']
        neuronResults=pd.DataFrame(columns=cols)

        for i, file in enumerate(neuron.filename):
            if i == 0:
                neuron.reset_index(inplace=True, drop=True)
        
            abf = pyabf.ABF(neuron.foldername[i]+"\\"+cellID+"\\"+file)
            print("Analysing"+file)
        
            for sweep in range(abf.sweepCount):    
                #Set voltage, current, time
                abf.setSweep(sweepNumber=sweep, channel=0)
                t = abf.sweepX
                V = abf.sweepY
                abf.setSweep(sweepNumber=sweep, channel=1)
                I = abf.sweepY
                sr = abf.dataRate
    
                if neuron.filetype[i]=='IntrinsicProfile':  
                    neuronResults.loc[len(neuronResults), :] = Analyse_IntrinsicProfile(V, I, t, sr, plotting)

                elif neuron.filetype[i]=='Rin':
                    Rin, Tau = Analyse_Rin(V, I, t, sr, plotting)

                elif neuron.filetype[i]=='Baseline':
                    RMP, rheobase, AP_threshold, AP_spikeHeight, AP_halfWidth, AP_fAHP = Analyse_Baseline(V, I, t, sr, plotting)
        
            
        if 'RMP' not in locals(): # Case there is not baseline file recorded
            print("No RMP")
            #RMP = np.mean(neuronResults.RMP)
            #rheobase = np.mean(neuronResults.Rheobase)
            #AP_threshold = np.mean(neuronResults.Threshold)
            #AP_spikeHeight = np.mean(neuronResults.SpikeHeight)
            #AP_halfWidth = np.mean(neuronResults.SpikeHalfWidth)
            #AP_fAHP = np.mean(neuronResults.fAHPamplitude)
            
            RMP = np.nan
            rheobase = np.nan
            AP_threshold = np.nan
            AP_spikeHeight = np.nan
            AP_halfWidth = np.nan
            AP_fAHP = np.nan
        
        if rheobase == 0: # Case baseline is recorded without valid current trace
            rheobase = np.mean(neuronResults.Rheobase)
        
        if 'Rin' not in locals():
            print("No Rin")
            Rin = np.nan
            Tau = np.nan
            
        #Build output dataframe
        MaxFiringFrequency = np.max(neuronResults.FiringFrequency)
        if not neuronResults.FiringFrequency.empty:
            Adaptation = neuronResults.Adaptation[neuronResults.FiringFrequency.astype('float64').idxmax()]
            VoltageSag = neuronResults.VoltageSag[np.argmin(abs(neuronResults.V_Ih_SS+100))[0]]
        else:
            print("List is empty")
            Adaptation = np.nan
            VoltageSag = np.nan
            
        if np.isnan(rheobase):
            rheobase = neuron.Rheobase[0]
        
        results = [cellID, neuron.CellTarget[0], neuron.Genotype[0], RMP, Rin, Tau, rheobase, AP_threshold, AP_spikeHeight, AP_halfWidth, MaxFiringFrequency, Adaptation, AP_fAHP, VoltageSag]
        #plt.figure()
        #plt.plot(neuronResults.CommandAmplitude,neuronResults.FiringFrequency,'o')
        return results

# %%
data = pd.read_csv("data.csv")
#Initialize results dataframe
resultsColumns = ['Cell_ID','CellTarget','Genotype','RMP','Rin','Tau','Rheobase','Spike_Threshold','Spike_Height','Spike_HalfWidth','MaxFiringFrequency','Adaptation', 'AHP_amplitude', 'VoltageSag']
results = pd.DataFrame(columns=resultsColumns)

for cellID in np.unique(data.Cell_ID):
    print(cellID)
    neuron=data[data.Cell_ID==cellID]
    
    results.loc[len(results), :] = Analyse_Neuron(neuron)
    
    
print(results)
# Out:
# Dlx1.1
# Analysing19o30000.abf
# Analysing19o30001.abf
# Analysing19o30002.abf
# Analysing19o30003.abf
# Analysing19o30004.abf
# Analysing19o30005.abf
# Analysing19o30006.abf
# Analysing19o30007.abf
# Analysing19o30008.abf
# Analysing19o30009.abf
# Analysing19o30010.abf
# Analysing19o30011.abf
# Analysing19o30012.abf
# Analysing19o30013.abf
# Analysing19o30014.abf
# Analysing19o30015.abf
# Analysing19o30016.abf
# Analysing19o30017.abf
# Analysing19o30018.abf
# Analysing19o30019.abf
# Analysing19o30020.abf
# Analysing19o30021.abf
# Analysing19o30021a.abf
# Analysing19o30022.abf
# Analysing19o30023.abf
# Analysing19o30024.abf
# Dlx1.2
# Analysing19o30025.abf
# Analysing19o30026.abf
# Analysing19o30027.abf
# Analysing19o30028.abf
# Analysing19o30029.abf
# Analysing19o30030.abf
# Analysing19o30031.abf
# Analysing19o30032.abf
# Analysing19o30033.abf
# Analysing19o30034.abf
# Analysing19o30035.abf
# Analysing19o30036.abf
# Dlx1.3
# Analysing19o30037.abf
# Analysing19o30038.abf
# Analysing19o30039.abf
# Analysing19o30040.abf
# Analysing19o30041.abf
# Analysing19o30042.abf
# Analysing19o30043.abf
# Analysing19o30044.abf
# Analysing19o30045.abf
# Analysing19o30046.abf
# Analysing19o30047.abf
# Analysing19o30048.abf
# Analysing19o30049.abf
# Analysing19o30050.abf
# Analysing19o30051.abf
# Analysing19o30052.abf
# Analysing19o30053.abf
# Dlx10.1
# Analysing19n15000.abf
# Analysing19n15001.abf
# Analysing19n15002.abf
# Analysing19n15003.abf
# Analysing19n15004.abf
# Analysing19n15005.abf
# Analysing19n15006.abf
# Analysing19n15007.abf
# Analysing19n15008.abf
# Analysing19n15009.abf
# Analysing19n15010.abf
# Analysing19n15011.abf
# Analysing19n15012.abf
# Analysing19n15013.abf
# Analysing19n15014.abf
# Analysing19n15015.abf
# Analysing19n15016.abf
# Analysing19n15017.abf
# Dlx10.2
# Analysing19n15018.abf
# Analysing19n15019.abf
# Analysing19n15020.abf
# Analysing19n15021.abf
# Analysing19n15022.abf
# Analysing19n15023.abf
# Analysing19n15024.abf
# Analysing19n15025.abf
# Analysing19n15026.abf
# Analysing19n15027.abf
# Analysing19n15028.abf
# Analysing19n15029.abf
# Dlx10.3
# Analysing19n15057.abf
# Analysing19n15058.abf
# Analysing19n15059.abf
# Analysing19n15060.abf
# Analysing19n15061.abf
# Analysing19n15062.abf
# Analysing19n15063.abf
# Analysing19n15064.abf
# Analysing19n15065.abf
# Analysing19n15066.abf
# Analysing19n15067.abf
# Analysing19n15068.abf
# Analysing19n15069.abf
# Analysing19n15070.abf
# Analysing19n15071.abf
# Analysing19n15072.abf
# Analysing19n15073.abf
# Dlx11.1
# Analysing19n15030.abf
# Analysing19n15031.abf
# Analysing19n15032.abf
# Analysing19n15033.abf
# Analysing19n15034.abf
# Analysing19n15035.abf
# Analysing19n15036.abf
# Analysing19n15037.abf
# Analysing19n15038.abf
# Analysing19n15039.abf
# Analysing19n15040.abf
# Analysing19n15041.abf
# Analysing19n15042.abf
# Analysing19n15043.abf
# Analysing19n15044.abf
# Dlx12.1
# Analysing19n15045.abf
# Analysing19n15046.abf
# Analysing19n15047.abf
# Analysing19n15048.abf
# Analysing19n15049.abf
# Analysing19n15050.abf
# Analysing19n15051.abf
# Analysing19n15052.abf
# Analysing19n15053.abf
# Analysing19n15054.abf
# Analysing19n15055.abf
# Analysing19n15056.abf
# Dlx4.1
# Analysing19n13000.abf
# Analysing19n13001.abf
# Analysing19n13002.abf
# Analysing19n13003.abf
# Analysing19n13004.abf
# Analysing19n13005.abf
# Analysing19n13006.abf
# Analysing19n13007.abf
# Analysing19n13008.abf
# Analysing19n13009.abf
# Analysing19n13010.abf
# Dlx4.2
# Analysing19n13011.abf
# Analysing19n13012.abf
# Analysing19n13013.abf
# Analysing19n13014.abf
# Analysing19n13015.abf
# Analysing19n13016.abf
# Analysing19n13017.abf
# Analysing19n13018.abf
# Analysing19n13019.abf
# Analysing19n13020.abf
# Analysing19n13021.abf
# Analysing19n13022.abf
# Analysing19n13023.abf
# Analysing19n13024.abf
# Analysing19n13025.abf
# Analysing19n13026.abf
# Analysing19n13027.abf
# Dlx4.3
# Analysing19n13028.abf
# Analysing19n13029.abf
# Analysing19n13030.abf
# Analysing19n13031.abf
# Analysing19n13032.abf
# Analysing19n13033.abf
# Analysing19n13034.abf
# Analysing19n13035.abf
# Analysing19n13036.abf
# Analysing19n13037.abf
# Analysing19n13038.abf
# Analysing19n13039.abf
# Analysing19n13040.abf
# Dlx4.4
# Analysing19n13041.abf
# Analysing19n13042.abf
# Analysing19n13043.abf
# Analysing19n13044.abf
# Analysing19n13045.abf
# Analysing19n13046.abf
# Analysing19n13047.abf
# Analysing19n13048.abf
# Analysing19n13049.abf
# Analysing19n13050.abf
# Analysing19n13051.abf
# Analysing19n13052.abf
# Analysing19n13053.abf
# Analysing19n13054.abf
# Analysing19n13055.abf
# Dlx4.5
# Analysing19n13056.abf
# Analysing19n13057.abf
# Analysing19n13058.abf
# Analysing19n13059.abf
# Analysing19n13060.abf
# Analysing19n13061.abf
# Analysing19n13062.abf
# Analysing19n13063.abf
# Analysing19n13064.abf
# Analysing19n13065.abf
# Analysing19n13066.abf
# Analysing19n13067.abf
# Analysing19n13068.abf
# Analysing19n13069.abf
# No Rin
# Dlx6.1
# Analysing19n13070.abf
# Analysing19n13071.abf
# Analysing19n13072.abf
# Analysing19n13073.abf
# Analysing19n13074.abf
# Analysing19n13075.abf
# Analysing19n13076.abf
# Analysing19n13077.abf
# Analysing19n13078.abf
# Analysing19n13079.abf
# Analysing19n13080.abf
# Analysing19n13081.abf
# Analysing19n13082.abf
# Analysing19n13083.abf
# Analysing19n13084.abf
# Analysing19n13085.abf
# Analysing19n13086.abf
# Analysing19n13087.abf
# Dlx6.2
# Analysing19n13088.abf
# Analysing19n13089.abf
# Analysing19n13090.abf
# Analysing19n13091.abf
# Analysing19n13092.abf
# Analysing19n13093.abf
# Analysing19n13094.abf
# Analysing19n13095.abf
# Analysing19n13096.abf
# Analysing19n13097.abf
# Analysing19n13098.abf
# Analysing19n13099.abf
# Analysing19n13100.abf
# Analysing19n13101.abf
# Analysing19n13102.abf
# Analysing19n13103.abf
# Analysing19n13104.abf
# No RMP
# Dlx7.1
# Analysing19n14000.abf
# Analysing19n14001.abf
# Analysing19n14002.abf
# Analysing19n14003.abf
# Analysing19n14004.abf
# Analysing19n14005.abf
# Analysing19n14006.abf
# Analysing19n14007.abf
# Analysing19n14008.abf
# Analysing19n14009.abf
# Analysing19n14010.abf
# Analysing19n14011.abf
# Analysing19n14012.abf
# Analysing19n14013.abf
# Analysing19n14014.abf
# Analysing19n14015.abf
# Analysing19n14016.abf
# Dlx7.2
# Analysing19n14000.abf
# Analysing19n14001.abf
# Analysing19n14002.abf
# Analysing19n14003.abf
# Analysing19n14004.abf
# Analysing19n14005.abf
# Analysing19n14005a.abf
# Analysing19n14006.abf
# Analysing19n14007.abf
# Analysing19n14008.abf
# Analysing19n14009.abf
# Analysing19n14010.abf
# Analysing19n14011.abf
# Dlx7.3
# Analysing19n14012.abf
# Analysing19n14013.abf
# Analysing19n14014.abf
# Analysing19n14015.abf
# Analysing19n14016.abf
# Analysing19n14017.abf
# Analysing19n14018.abf
# No RMP
# No Rin
# List is empty
# Dlx7.4
# Analysing19n14017.abf
# Analysing19n14018.abf
# Analysing19n14019.abf
# Analysing19n14020.abf
# Analysing19n14021.abf
# Analysing19n14022.abf
# Analysing19n14023.abf
# Analysing19n14024.abf
# Analysing19n14025.abf
# Analysing19n14026.abf
# Analysing19n14027.abf
# Analysing19n14028.abf
# Analysing19n14029.abf
# Analysing19n14030.abf
# Analysing19n14031.abf
# Analysing19n14032.abf
# Dlx8.1
# Analysing19n14033.abf
# Analysing19n14034.abf
# Analysing19n14035.abf
# Analysing19n14036.abf
# Analysing19n14037.abf
# Analysing19n14038.abf
# Analysing19n14039.abf
# Analysing19n14040.abf
# Analysing19n14041.abf
# Analysing19n14042.abf
# Analysing19n14043.abf
# Analysing19n14044.abf
# Analysing19n14045.abf
# Analysing19n14046.abf
# Analysing19n14047.abf
# Analysing19n14048.abf
# Dlx8.2
# Analysing19n14049.abf
# Analysing19n14050.abf
# Analysing19n14051.abf
# Analysing19n14052.abf
# Analysing19n14053.abf
# Analysing19n14054.abf
# Analysing19n14055.abf
# Analysing19n14056.abf
# Analysing19n14057.abf
# Analysing19n14058.abf
# Analysing19n14059.abf
# Analysing19n14060.abf
# Analysing19n14061.abf
# Analysing19n14062.abf
# Analysing19n14063.abf
# Analysing19n14064.abf
# Analysing19n14065.abf
# Analysing19n14066.abf
# Analysing19n14067.abf
# Analysing19n14068.abf
# Analysing19n14069.abf
# Analysing19n14070.abf
# Analysing19n14071.abf
# Analysing19n14072.abf
# Analysing19n14073.abf
# Analysing19n14074.abf
# Analysing19n14075.abf
# Analysing19n14076.abf
# Dlx8.3
# Analysing19n14077.abf
# Analysing19n14078.abf
# Analysing19n14079.abf
# Analysing19n14080.abf
# Analysing19n14081.abf
# Analysing19n14082.abf
# Analysing19n14083.abf
# Analysing19n14084.abf
# Analysing19n14085.abf
# Analysing19n14086.abf
# Analysing19n14087.abf
# Analysing19n14088.abf
# Analysing19n14089.abf
# Analysing19n14090.abf
# Dlx9.1
# Analysing19n14019.abf
# Analysing19n14020.abf
# Analysing19n14021.abf
# Analysing19n14022.abf
# Analysing19n14022a.abf
# Analysing19n14023.abf
# Analysing19n14024.abf
# Dlx9.2
# Analysing19n14025.abf
# Analysing19n14026.abf
# Analysing19n14027.abf
# Analysing19n14027a.abf
# Analysing19n14028.abf
# Analysing19n14029.abf
# Analysing19n14030.abf
# Dlx9.3
# Analysing19n14032.abf
# Analysing19n14033.abf
# Analysing19n14034.abf
# Analysing19n14035.abf
# Analysing19n14036.abf
# Analysing19n14037.abf
# Analysing19n14038.abf
# Analysing19n14039.abf
# Analysing19n14040.abf
#     Cell_ID CellTarget Genotype      RMP      Rin         Tau Rheobase  \
# 0    Dlx1.1     Dlx5/6      Het  -63.893  355.208   0.0107895       27
# 1    Dlx1.2     Dlx5/6      Het -70.2951  210.275   0.0281636  72.0215
# 2    Dlx1.3     Dlx5/6      Het -67.6934  209.541   0.0292347  103.149
# 3   Dlx10.1     Dlx5/6    fl/fl -69.0034  421.217   0.0509421  53.7109
# 4   Dlx10.2     Dlx5/6    fl/fl -74.4253  382.893   0.0205315   104.37
# 5   Dlx10.3     Dlx5/6    fl/fl -65.7241  1464.03   0.0544211  23.8037
# 6   Dlx11.1     Dlx5/6    fl/fl -69.2068  380.083   0.0232017  101.929
# 7   Dlx12.1     Dlx5/6      Het -74.4512  235.278    0.021288  128.784
# 8    Dlx4.1     Dlx5/6    fl/fl -76.1231  313.528   0.0262967       60
# 9    Dlx4.2     Dlx5/6    fl/fl  -61.428  210.888    0.030368       30
# 10   Dlx4.3     Dlx5/6    fl/fl -63.8266  265.668   0.0330461       50
# 11   Dlx4.4     Dlx5/6    fl/fl -67.1315  674.957   0.0665683       40
# 12   Dlx4.5     Dlx5/6    fl/fl -70.2377      NaN         NaN       70
# 13   Dlx6.1     Dlx5/6      Het -69.6917  198.864   0.0161193      180
# 14   Dlx6.2     Dlx5/6      Het      NaN  278.985   0.0145848       65
# 15   Dlx7.1     Dlx5/6      Mut -71.3327  297.997    0.039335   104.37
# 16   Dlx7.2     Dlx5/6      Mut -77.1254  375.497   0.0153184  97.6562
# 17   Dlx7.3     Dlx5/6      Mut      NaN      NaN         NaN       60
# 18   Dlx7.4     Dlx5/6      Mut -67.3214  303.965   0.0489343  101.929
# 19   Dlx8.1     Dlx5/6      Het -68.9315  256.229   0.0330377  154.419
# 20   Dlx8.2     Dlx5/6      Het -63.6698  223.771  0.00990528  44.5557
# 21   Dlx8.3     Dlx5/6      Het -72.2026  331.161    0.037047  106.812
# 22   Dlx9.1     Dlx5/6      Het -62.5339  86.4299   0.0093921   260.01
# 23   Dlx9.2     Dlx5/6      Het -59.9447  292.827   0.0263257  48.2178
# 24   Dlx9.3        Pyr      Het -72.1495  199.154   0.0226179  197.144
#
#    Spike_Threshold Spike_Height Spike_HalfWidth MaxFiringFrequency Adaptation  \
# 0         -40.1001      67.1387         0.00165                 70    33.3333
# 1         -43.2129      57.7087         0.00175                 58       37.5
# 2         -50.3235       50.415         0.08875                 76         40
# 3         -42.2363      67.2302         0.00165                 40         50
# 4         -44.9829      62.1338          0.0017                 48       62.5
# 5         -43.1519      66.6504         0.05395                 48    33.3333
# 6         -40.1611       44.281         0.00155                 66         50
# 7         -44.1284      57.4951         0.00115                 92    33.3333
# 8         -41.3513      65.1245         0.00165                 42         20
# 9         -47.2717       73.761         0.00155                 48          0
# 10        -37.0483      51.0559          0.0022                 52    16.6667
# 11        -38.7878      53.7415         0.00165                 50          0
# 12        -38.1165      35.2783          0.0023                 56    28.5714
# 13        -29.2053      33.6304         0.00115                122   -9.09091
# 14             NaN          NaN             NaN                128    26.6667
# 15        -46.2646      58.7769         0.00155                 64       37.5
# 16        -38.2385      58.7463           0.002                 76         50
# 17             NaN          NaN             NaN                NaN        NaN
# 18        -42.6636      67.2607          0.0017                 54       37.5
# 19        -65.4602      76.1108         0.00185                 60    44.4444
# 20        -48.4619      55.2979          0.0012                102    30.7692
# 21         -44.281      48.0347         0.00125                 76         40
# 22        -40.0696      52.7039          0.0699                 74    45.4545
# 23        -35.2173       49.469          0.0027                 50         50
# 24        -35.0647      67.3218          0.0022                 26        100
#
#    AHP_amplitude VoltageSag
# 0        18.1885    3.26538
# 1        13.6108    2.74658
# 2        9.46045    4.76074
# 3        14.8621    12.0544
# 4        10.0403   0.579834
# 5        16.7542    1.19019
# 6        11.1694    3.54004
# 7        18.4326    1.46484
# 8        16.2354    1.06812
# 9        11.3831    2.68555
# 10       25.3601    2.62451
# 11       21.5149   0.610352
# 12       12.7258    1.40381
# 13       21.3623    2.53296
# 14           NaN     4.5166
# 15       10.8337     3.9978
# 16       14.7095 -0.0915527
# 17           NaN        NaN
# 18       10.7727    1.58691
# 19      -5.40161    6.65283
# 20       14.1602    4.18091
# 21       21.5759    3.87573
# 22       10.5286    1.64795
# 23       16.2354     2.7771
# 24        20.874   0.579834

# %%
#Plot useful stuff
    fig=plt.figure(figsize=(16, 10))
    ax1 = fig.add_subplot(211)
    ax1.plot(t,V)
    #ax2 = fig.add_subplot(212)
    #ax2.plot(t,I)
    #ax1.plot(t[I_ON:I_OFF],V[I_ON:I_OFF])


    if np.shape(V_peaks)[0] != 0:
        #ax1.plot(t[I_ON+int(0.04*sr):V_peaks[0]],V[I_ON+int(0.04*sr):V_peaks[0]]) #Zoom for threshold check
        #ax1.plot(t[I_ON+int(0.04*sr):V_peaks[0]+int(0.01*sr)],V[I_ON+int(0.04*sr):V_peaks[0]+int(0.01*sr)]) #Zoom for threshold check
        ax1.plot(t[V_peaks],V[V_peaks],"rx")

    if np.shape(V_peaks)[0] in [1,2,3]:
        ax1.plot(t[Th_idx],V[Th_idx],"rx")
        ax1.plot(t[Half_Start],V[Half_Start],'rx')
        ax1.plot(t[Half_End],V[Half_End],'rx')
        ax1.plot(t[fAHP_idx],V[fAHP_idx],'rx')


        ax2 = fig.add_subplot(212)
        ax2.plot(t[I_ON+int(0.04*sr):V_peaks[0]],dV[I_ON+int(0.04*sr):V_peaks[0]])
        ax2.plot(t[Th_idx],dV[Th_idx],"rx")

        fig2 = plt.figure(figsize=(16, 10))
        plt.plot(V,dV)

    if I_command < 0:
        ax1.plot(t[V_Ih_inst_idx],V[V_Ih_inst_idx],"rx")
        ax1.plot(t[I_OFF],V[I_OFF],"rx")

# %%
from scipy.signal import butter, lfilter
def butter_lowpass(lowcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    b, a = butter(order, low, btype='low')
    return b, a


def butter_lowpass_filter(data, lowcut, fs, order):
    b, a = butter_lowpass(lowcut, fs, order)
    y = lfilter(b, a, data)
    return y
