# %%
import pandas as pd
from IntrinsicProfiles_Functions import Analyse_Neuron
pd.set_option('display.max_rows', 200)

# %%
# Inputs
data = pd.read_csv("C:\\Users\\Butt Lab\\OneDrive - OnTheHub - The University of Oxford\\TheBible.csv")
data = data[data.Experiment=='IntrinsicProfile']
data = data[data.Discard==0]

cellIDs=np.unique(data.CellID)
# cellIDs=['SA134.8']

#Initialize results dataframe
resultsColumns = ['Cell_ID','Age','Development','BrainArea','CellTarget','CellType','CellLayer','RMP','Rin','Tau','Rheobase','AP_Threshold','AP_Height','AP_HalfWidth','AP_AHP','MaxFiringFrequency','AdaptationIndex','VoltageSag']
results = pd.DataFrame(columns=resultsColumns)
for cellID in cellIDs:
    print(cellID)
    neuron=data[data.CellID==cellID]    
    results.loc[len(results), :] = Analyse_Neuron(neuron, plotting=False)
results.to_csv('IntrinsicProfiles_Results.csv')
# Out:
# SA103.1
# Analysing20731001.abf
# SA103.2
# Analysing20731011.abf
# SA103.3
# Analysing20731014.abf
# SA103.4
# Analysing20731020.abf
# SA103.5
# Analysing20731026.abf
# SA107.1
# Analysing20804003.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA107.2
# Analysing20804009.abf
# SA107.3
# Analysing20804014.abf
# SA107.4
# Analysing20804023.abf
# SA108.1
# Analysing20805001.abf
# SA109.1
# Analysing20805012.abf
# SA109.2
# Analysing20805015.abf
# SA109.3
# Analysing20805021.abf
# SA109.4
# Analysing20805026.abf
# SA111.1
# Analysing20901001.abf
# SA111.2
# Analysing20901007.abf
# SA111.3
# Analysing20901016.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA111.4
# Analysing20901023.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA120.1
# Analysing20o05011.abf
# SA120.2
# Analysing20o05017.abf
# SA120.3
# Analysing20o05024.abf
# SA121.1
# Analysing20o05004.abf
# SA122.1
# Analysing20o06005.abf
# SA122.2
# Analysing20o06010.abf
# SA122.3
# Analysing20o06029.abf
# SA122.4
# Analysing20o06036.abf
# SA123.1
# Analysing20o06016.abf
# SA123.2
# Analysing20o06022.abf
# SA129.1
# Analysing20o09001.abf
# SA129.2
# Analysing20o09008.abf
# SA129.3
# Analysing20o09014.abf
# SA130.1
# Analysing20n02002.abf
# SA130.2
# Analysing20n02008.abf
# SA130.3
# Analysing20n02014.abf
# SA130.4
# Analysing20n02019.abf
# SA130.5
# Analysing20n02025.abf
# SA131.1
# Analysing20n04002.abf
# SA131.2
# Analysing20n04009.abf
# SA131.3
# Analysing20n04015.abf
# SA131.4
# Analysing20n04020.abf
# SA132.2
# Analysing20n04029.abf
# SA133.1
# Analysing20n09004.abf
# SA133.2
# Analysing20n09012.abf
# SA133.3
# Analysing20n09016.abf
# SA133.5
# Analysing20n09025.abf
# SA134.1
# Analysing20n23004.abf
# SA134.2
# Analysing20n23009.abf
# SA134.3
# Analysing20n23013.abf
# SA134.4
# Analysing20n23019.abf
# SA134.5
# Analysing20n23024.abf
# SA134.6
# Analysing20n23029.abf
# SA134.7
# Analysing20n23034.abf
# SA134.8
# Analysing20n23039.abf
# SA134.9
# Analysing20n23045.abf
# SA83.1
# Analysing20623001.abf
# SA83.2
# Analysing20623006.abf
# SA83.3
# Analysing20623011.abf
# SA83.4
# Analysing20623018.abf
# SA84.1
# Analysing20623022.abf
# SA85.1
# Analysing20625018.abf
# SA85.2
# Analysing20625026.abf
# SA85.3
# Analysing20625031.abf
# SA86.1
# Analysing20625002.abf
# SA86.2
# Analysing20625010.abf
# SA87.1
# Analysing20717004.abf
# SA88.1
# Analysing20717009.abf
# SA88.2
# Analysing20717018.abf
# SA88.3
# Analysing20717029.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA88.4
# Analysing20717029.abf
# SA89.1
# Analysing20717022.abf
# SA89.2
# Analysing20717039.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA90.1
# Analysing20722001.abf
# SA90.2
# Analysing20722001.abf
# SA91.1
# Analysing20722007.abf
# SA91.2
# Analysing20722016.abf
# SA91.3
# Analysing20722020.abf
# SA92.1
# Analysing20723001.abf
# SA92.3
# Analysing20723014.abf
# SA92.4
# Analysing20723022.abf
# SA94.1
# Analysing20727002.abf
# SA94.2
# Analysing20727008.abf
# SA94.3
# Analysing20727016.abf
# SA94.4
# Analysing20727025.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SA94.5
# Analysing20727030.abf
# SA94.6
# Analysing20727037.abf
# SA94.7
# Analysing20727047.abf
# SA96.1
# Analysing20728005.abf
# SA96.2
# Analysing20728011.abf
# SA96.3
# Analysing20728020.abf
# SA96.4
# Analysing20728032.abf
# SA96.5
# Analysing20728036.abf
# SA99.1
# Analysing20729001.abf
# SA99.2
# Analysing20729007.abf
# SA99.3
# Analysing20729020.abf
# SX23.3
# Analysing20708040.abf
# SX23.4
# Analysing20708049.abf
# SX23.5
# Analysing20708053.abf
# SX34.1
# Analysing20812003.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX34.2
# Analysing20812010.abf
# SX34.3
# Analysing20812014.abf
# SX34.4
# Analysing20812020.abf
# SX35.1
# Analysing20814003.abf
# SX35.2
# Analysing20814009.abf
# SX35.3
# Analysing20814016.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX35.4
# Analysing20814023.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX35.5
# Analysing20814030.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX35.6
# Analysing20814034.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX35.7
# Analysing20814042.abf
# SX35.8
# Analysing20814049.abf
# SX39.2
# Analysing20818007.abf
# SX39.3
# Analysing20818013.abf
# SX39.4
# Analysing20818020.abf
# SX39.5
# Analysing20818025.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX39.6
# Analysing20818031.abf
# SX44.2
# Analysing20821001.abf
# SX44.3
# Analysing20821007.abf
# SX47.1
# Analysing20825002.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX47.2
# Analysing20825009.abf
# SX49.1
# Analysing20825017.abf
# SX49.2
# Analysing20825024.abf
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Butt Lab\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SX67.1
# Analysing20n12013.abf
#      Cell_ID Age Development BrainArea   CellTarget CellType CellLayer  \
# 0    SA103.1  17     P14-P18      S1BF    Pyramidal      Pyr         4
# 1    SA103.2  17     P14-P18      S1BF         LHX6       PV         4
# 2    SA103.3  17     P14-P18      S1BF         LHX6       PV         4
# 3    SA103.4  17     P14-P18      S1BF    Pyramidal      Pyr         4
# 4    SA103.5  17     P14-P18      S1BF         LHX6       PV         4
# 5    SA107.1  17     P14-P18        V1    Pyramidal      Pyr         4
# 6    SA107.2  17     P14-P18        V1    Pyramidal      Pyr         4
# 7    SA107.3  17     P14-P18        V1  LHX6;SSTCre      SST         4
# 8    SA107.4  17     P14-P18        V1         LHX6       PV         4
# 9    SA108.1  18     P14-P18      S1BF         LHX6       PV         4
# 10   SA109.1  18     P14-P18      S1BF       SSTCre      SST         4
# 11   SA109.2  18     P14-P18      S1BF       SSTCre      SST         4
# 12   SA109.3  18     P14-P18      S1BF       SSTCre      SST         5
# 13   SA109.4  18     P14-P18      S1BF       SSTCre      SST         4
# 14   SA111.1   6       P5-P8      S1BF    Pyramidal      Pyr         4
# 15   SA111.2   6       P5-P8      S1BF    Pyramidal      Pyr         4
# 16   SA111.3   6       P5-P8      S1BF    Pyramidal      Pyr         4
# 17   SA111.4   6       P5-P8      S1BF    Pyramidal      Pyr         4
# 18   SA120.1   7       P5-P8      S1BF       SSTCre      SST         4
# 19   SA120.2   7       P5-P8      S1BF       SSTCre      SST         4
# 20   SA120.3   7       P5-P8      S1BF    Pyramidal      Pyr         4
# 21   SA121.1   7       P5-P8      S1BF    Pyramidal      Pyr         4
# 22   SA122.1   8       P5-P8      S1BF       SSTCre       FS         4
# 23   SA122.2   8       P5-P8      S1BF       SSTCre      SST         4
# 24   SA122.3   8       P5-P8      S1BF       SSTCre      SST         4
# 25   SA122.4   8       P5-P8      S1BF    Pyramidal      Pyr         4
# 26   SA123.1   8       P5-P8      S1BF       SSTCre      SST         4
# 27   SA123.2   8       P5-P8      S1BF    Pyramidal      Pyr         4
# 28   SA129.1   6       P5-P8        V1       SSTCre      SST         5
# 29   SA129.2   6       P5-P8        V1       SSTCre      SST         4
# 30   SA129.3   6       P5-P8        V1    Pyramidal      Pyr         4
# 31   SA130.1   6       P5-P8      S1BF         LHX6       PV        23
# 32   SA130.2   6       P5-P8      S1BF         LHX6      SST         4
# 33   SA130.3   6       P5-P8      S1BF         LHX6       PV         4
# 34   SA130.4   6       P5-P8      S1BF         LHX6       PV         4
# 35   SA130.5   6       P5-P8      S1BF         LHX6       PV         5
# 36   SA131.1  12      P9-P13        V1         LHX6      SST         4
# 37   SA131.2  12      P9-P13      S1BF    Pyramidal      Pyr         4
# 38   SA131.3  12      P9-P13      S1BF         LHX6      SST         4
# 39   SA131.4  12      P9-P13      S1BF         LHX6       PV         4
# 40   SA132.2   8       P5-P8        V1    Pyramidal      Pyr         4
# 41   SA133.1  17     P14-P18      S1BF         LHX6      SST         5
# 42   SA133.2  17     P14-P18      S1BF         LHX6       PV         4
# 43   SA133.3  17     P14-P18      S1BF         LHX6       PV         4
# 44   SA133.5  17     P14-P18      S1BF    Pyramidal      Pyr         4
# 45   SA134.1   7       P5-P8      S1BF       SSTCre      SST         5
# 46   SA134.2   7       P5-P8      S1BF       SSTCre      SST         5
# 47   SA134.3   7       P5-P8      S1BF       SSTCre      SST        23
# 48   SA134.4   7       P5-P8      S1BF       SSTCre      SST         4
# 49   SA134.5   7       P5-P8      S1BF       SSTCre      SST         4
# 50   SA134.6   7       P5-P8        V1       SSTCre      SST         4
# 51   SA134.7   7       P5-P8        V1       SSTCre      SST         4
# 52   SA134.8   7       P5-P8        V1         LHX6       PV         4
# 53   SA134.9   7       P5-P8        V1    Pyramidal      Pyr         4
# 54    SA83.1  11      P9-P13        V1         LHX6       PV         4
# 55    SA83.2  11      P9-P13        V1         LHX6       PV         4
# 56    SA83.3  11      P9-P13        V1  LHX6;SSTCre      SST         4
# 57    SA83.4  11      P9-P13        V1         LHX6       PV         4
# 58    SA84.1  11      P9-P13        V1       SSTCre      SST         4
# 59    SA85.1  13     P14-P18        V1       SSTCre      SST         4
# 60    SA85.2  13     P14-P18        V1       SSTCre      SST         4
# 61    SA85.3  13     P14-P18        V1       SSTCre      SST         4
# 62    SA86.1  13     P14-P18        V1       SSTCre      SST         4
# 63    SA86.2  13     P14-P18        V1       SSTCre      SST         4
# 64    SA87.1  16     P14-P18        V1    Pyramidal       FS         4
# 65    SA88.1  16     P14-P18        V1         LHX6       PV         4
# 66    SA88.2  16     P14-P18        V1         LHX6       PV         4
# 67    SA88.3  16     P14-P18      S1BF         LHX6       PV         4
# 68    SA88.4  16     P14-P18      S1BF    Pyramidal      Pyr         4
# 69    SA89.1  16     P14-P18        V1         LHX6       PV         4
# 70    SA89.2  16     P14-P18        V1         LHX6       PV         4
# 71    SA90.1   8       P5-P8        V1       SSTCre      SST         4
# 72    SA90.2   8       P5-P8        V1    Pyramidal      Pyr         4
# 73    SA91.1   8       P5-P8        V1         LHX6       PV         4
# 74    SA91.2   8       P5-P8        V1         LHX6       PV         4
# 75    SA91.3   8       P5-P8        V1  LHX6;SSTCre      SST         4
# 76    SA92.1   9      P9-P13        V1       SSTCre      SST         4
# 77    SA92.3   9      P9-P13      S1BF    Pyramidal      Pyr         4
# 78    SA92.4   9      P9-P13      S1BF       SSTCre      SST         4
# 79    SA94.1   9      P9-P13        V1         LHX6       PV         4
# 80    SA94.2   9      P9-P13      S1BF         LHX6       PV         4
# 81    SA94.3   9      P9-P13      S1BF         LHX6       PV         4
# 82    SA94.4   9      P9-P13      S1BF         LHX6       PV         4
# 83    SA94.5   9      P9-P13      S1BF       SSTCre      SST         4
# 84    SA94.6   9      P9-P13      S1BF       SSTCre      SST         4
# 85    SA94.7   9      P9-P13      S1BF    Pyramidal      Pyr         4
# 86    SA96.1  10      P9-P13        V1  LHX6;SSTCre      SST         4
# 87    SA96.2  10      P9-P13        V1         LHX6       PV         4
# 88    SA96.3  10      P9-P13        V1         LHX6       PV         4
# 89    SA96.4  10      P9-P13        V1         LHX6       PV         4
# 90    SA96.5  10      P9-P13        V1         LHX6       PV         5
# 91    SA99.1  15     P14-P18      S1BF    Pyramidal      Pyr         4
# 92    SA99.2  15     P14-P18      S1BF    Pyramidal      Pyr         4
# 93    SA99.3  15     P14-P18      S1BF       SSTCre       FS         4
# 94    SX23.3  13     P14-P18        V1    Pyramidal      Pyr         4
# 95    SX23.4  13     P14-P18        V1    Pyramidal      Pyr         4
# 96    SX23.5  13     P14-P18        V1    Pyramidal      Pyr         4
# 97    SX34.1   7       P5-P8        V1         LHX6       ND         4
# 98    SX34.2   7       P5-P8        V1    Pyramidal      Pyr         4
# 99    SX34.3   7       P5-P8        V1         LHX6       PV         4
# 100   SX34.4   7       P5-P8        V1         LHX6       PV         4
# 101   SX35.1   9      P9-P13        V1    Pyramidal      Pyr         4
# 102   SX35.2   9      P9-P13        V1    Pyramidal      Pyr         4
# 103   SX35.3   9      P9-P13      S1BF         LHX6       PV         4
# 104   SX35.4   9      P9-P13      S1BF    Pyramidal      Pyr         4
# 105   SX35.5   9      P9-P13      S1BF    Pyramidal      Pyr         4
# 106   SX35.6   9      P9-P13      S1BF         LHX6      SST         4
# 107   SX35.7   9      P9-P13        V1         LHX6       PV         4
# 108   SX35.8   9      P9-P13        V1    Pyramidal      Pyr         4
# 109   SX39.2  11      P9-P13        V1    Pyramidal      Pyr         4
# 110   SX39.3  11      P9-P13        V1    Pyramidal      Pyr         4
# 111   SX39.4  11      P9-P13      S1BF    Pyramidal      Pyr         4
# 112   SX39.5  11      P9-P13      S1BF    Pyramidal      Pyr         4
# 113   SX39.6  11      P9-P13      S1BF    Pyramidal      Pyr         4
# 114   SX44.2  16     P14-P18      S1BF         LHX6       PV         4
# 115   SX44.3  16     P14-P18      S1BF       SSTCre      SST         4
# 116   SX47.1  17     P14-P18      S1BF    Pyramidal      Pyr         4
# 117   SX47.2  17     P14-P18      S1BF    Pyramidal      Pyr         4
# 118   SX49.1  17     P14-P18      S1BF         LHX6       PV         4
# 119   SX49.2  17     P14-P18      S1BF         LHX6       PV         4
# 120   SX67.1  17     P14-P18      S1BF         LHX6      SST         4
#
#          RMP      Rin         Tau Rheobase AP_Threshold AP_Height  \
# 0   -76.5352  375.783   0.0249951       40     -36.6516   68.4204
# 1   -61.3513   62.443   -0.632751    189.5     -46.3867    75.592
# 2   -55.0819  89.6693    0.238834  155.846     -44.2505   62.8662
# 3   -80.0854  299.098   0.0232085       30     -41.3818   72.0825
# 4   -65.4002  61.6515    0.784452  357.333     -31.8298   54.2297
# 5   -75.6169  294.693   0.0247894       30     -41.3818   65.3381
# 6   -73.4759  349.954   0.0490651       20     -38.0249   62.2253
# 7   -61.6712  229.175   0.0201411  35.6154     -42.1448   58.8379
# 8   -71.0392  198.958   0.0119308  46.2174     -36.6211   68.2068
# 9   -74.6069   159.71   0.0135037  140.286     -36.1633   63.4155
# 10  -70.4055  107.145     2.92787  209.889     -37.9944   57.9224
# 11  -67.2701   110.03    0.681627  104.846     -45.3796   77.7283
# 12  -64.7036  338.763     1.56919       10     -43.2129   46.1731
# 13   -65.703  153.621     1.17979  67.6667      -40.741   58.4412
# 81       0.00135   21.1487                 60         1.40868    5.74002
# 82       0.00105   20.0806                 34         1.41599    1.32007
# 83        0.0013   14.4958                 70         1.28458    1.42996
# 84       0.00145   17.5171                 70         1.46914    5.78555
# 85       0.00255   7.84302                 38         1.60712     13.086
# 86       0.00215   9.70459                 70         1.22823   0.253845
# 87        0.0017   16.9983                 66         1.42888    4.22849
# 88        0.0014   16.2354                 68         1.16573     6.2243
# 89       0.00125   17.8528                 64         1.61834    4.39005
# 90       0.00135   12.5427                 94         1.25806    5.95532
# 91        0.0019   8.14819                 30         1.98757    3.93848
# 92        0.0027   3.05176                 30         1.71415    2.44119
# 93        0.0007   21.4844                100         1.28571    2.32053
# 94       0.00335    1.0376                 30         1.26054   0.878723
# 95       0.00275   2.22778                 30        0.960159   0.703949
# 96       0.00305   4.18091                 40         1.27653    1.82187
# 97       0.00225   10.9253                 56         1.36697   0.224365
# 98         0.003   5.58472                 16         1.43381   0.761292
# 99        0.0021   8.63647                 68         1.25922   0.460327
# 100      0.00185   22.2473                 52         1.18648   0.306488
# 101      0.00295   7.20215                 30         1.54894    3.39691
# 102      0.00275   10.1929                 30         1.17223     8.1051
# 103       0.0014   12.6648                 78         1.48621    11.5892
# 104      0.00245   6.19507                 30         1.24125    5.22641
# 105      0.00225   9.33838                 26         1.48477    6.57748
# 106       0.0015   14.3127                 72         1.41298    6.67368
# 107       0.0019   20.0806                 58         1.08077   0.489746
# 108       0.0023   5.79834                 60         1.24204    2.24496
# 109       0.0023   7.69043                 34         1.29115   0.347321
# 110      0.00285    5.7373                 34         1.18736   0.275269
# 111       0.0017   4.91333                 22         1.85972    3.17685
# 112      0.00235   3.05176                 36         5.06637    4.15775
# 113      0.00175   8.17871                 42         1.75669     2.3295
# 114       0.0009   16.2964                106         1.16889    2.21124
# 115      0.00115   5.67627                 54         1.59663    10.0368
# 116      0.00165   7.04956                 34         1.49047    8.82666
# 117       0.0017    5.0354                 16         13.8368    1.87781
# 118       0.0005    14.801                194        0.326879    3.13214
# 119      0.00055   17.2729                132         1.05372    3.09671
# 120       0.0013   5.40161                 66         1.36258    6.98883

# %%
results.groupby(['CellLayer','BrainArea','Development','CellType'])["Cell_ID"].count()
# Out:
# CellLayer  BrainArea  Development  CellType
# 4          S1BF       P14-P18      FS           1
#                                    PV          10
#                                    Pyr          8
#                                    SST          5
#                       P5-P8        FS           1
#                                    PV           2
#                                    Pyr          8
#                                    SST          8
#                       P9-P13       PV           5
#                                    Pyr          8
#                                    SST          5
#            V1         P14-P18      FS           1
#                                    PV           5
#                                    Pyr          5
#                                    SST          6
#                       P5-P8        ND           1
#                                    PV           5
#                                    Pyr          5
#                                    SST          5
#                       P9-P13       PV           8
#                                    Pyr          5
#                                    SST          5
# 5          S1BF       P14-P18      SST          2
#                       P5-P8        PV           1
#                                    SST          2
#            V1         P5-P8        SST          1
#                       P9-P13       PV           1
# 23         S1BF       P5-P8        PV           1
#                                    SST          1
# Name: Cell_ID, dtype: int64

# %%
import seaborn as sns
plt.figure
sns.scatterplot(x='AP_HalfWidth', y='MaxFiringFrequency', hue='CellType',data=results)
plt.xlim(0, 0.005)
# Out:
# (0, 0.005)

# %%
resultsPlotting=results[(results.CellType!='FS')&(results.CellType!='ND')&(results.CellLayer==4)]

g = sns.catplot(x="Development", y="MaxFiringFrequency", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="violin",height=5, aspect=1);
g = sns.catplot(x="Development", y="RMP", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="Rin", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="Rheobase", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="AP_Threshold", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="AP_Height", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="AP_HalfWidth", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="AP_AHP", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="Tau", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="AdaptationIndex", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
g = sns.catplot(x="Development", y="VoltageSag", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in fit_kde(self, x, bw)
#     716         try:
# --> 717             kde = stats.gaussian_kde(x, bw)
#     718         except TypeError:
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     539
# --> 540         self._compute_covariance()
#     541
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     550                                                bias=False,
# --> 551                                                aweights=self.weights))
#     552             self._data_inv_cov = linalg.inv(self._data_covariance)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2426
# -> 2427     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2428     w_sum = w_sum[0]
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     418
# --> 419         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     420         if np.any(scl == 0.0):
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: No loop matching the specified signature and casting
# was found for ufunc add
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-7898b7bf27ce> in <module>
#       1 resultsPlotting=results[(results.CellType!='FS')&(results.CellType!='ND')&(results.CellLayer==4)]
#       2
# ----> 3 g = sns.catplot(x="Development", y="MaxFiringFrequency", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="violin",height=5, aspect=1);
#       4 g = sns.catplot(x="Development", y="RMP", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
#       5 g = sns.catplot(x="Development", y="Rin", hue="CellType", col='BrainArea', order=['P5-P8','P9-P13','P14-P18'], data=resultsPlotting, kind="box",height=5, aspect=1);
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
#    3757     # Special case axis labels for a count type plot
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
#     819             # Draw the plot
# --> 820             self._facet_plot(func, ax, args, kwargs)
#     821
#     822         # Finalize the annotations and layout
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
#    2388
#    2389     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     562         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     563         self.establish_colors(color, palette, saturation)
# --> 564         self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#     565
#     566         self.gridsize = gridsize
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in estimate_densities(self, bw, cut, scale, scale_hue, gridsize)
#     677
#     678                     # Fit the KDE and get the used bandwidth size
# --> 679                     kde, bw_used = self.fit_kde(kde_data, bw)
#     680
#     681                     # Determine the support grid and get the density over it
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in fit_kde(self, x, bw)
#     717             kde = stats.gaussian_kde(x, bw)
#     718         except TypeError:
# --> 719             kde = stats.gaussian_kde(x)
#     720             if bw != "scott":  # scipy default
#     721                 msg = ("Ignoring bandwidth choice, "
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     538             raise ValueError(msg)
#     539
# --> 540         self._compute_covariance()
#     541
#     542     def _compute_covariance(self):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     549             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     550                                                bias=False,
# --> 551                                                aweights=self.weights))
#     552             self._data_inv_cov = linalg.inv(self._data_covariance)
#     553
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2425             w *= aweights
#    2426
# -> 2427     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2428     w_sum = w_sum[0]
#    2429
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     417             wgt = wgt.swapaxes(-1, axis)
#     418
# --> 419         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     420         if np.any(scl == 0.0):
#     421             raise ZeroDivisionError(
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting
# was found for ufunc add

# %%
afrom sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

## Do tSNE
results2=results.drop([35])
for col in ['RMP', 'Rin', 'Tau','Rheobase','AP_Threshold', 'AP_Height', 'AP_HalfWidth', 'AP_AHP', 'MaxFiringFrequency', 'AdaptationIndex', 'VoltageSag']:
    results2[col] = results2[col].astype(float)
results2["LogAdaptationIndex"] = np.log(results2.AdaptationIndex)
data = results2[['RMP', 'Rin', 'Rheobase' , 'AP_HalfWidth', 'AP_AHP','VoltageSag', 'LogAdaptationIndex', 'AP_Threshold', 'AP_Height', 'MaxFiringFrequency']].to_numpy(dtype=float)#'Tau', 
z_data = StandardScaler().fit_transform(data)
plt.imshow(z_data, aspect='auto')

## tSNE plot
X_embedded = TSNE(perplexity = 6, method = 'exact').fit_transform(z_data)
#perplexity = 15, method = 'exact', random_state = 42
plt.figure(figsize=(20,12))
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue="CellType", data=results2, legend="full", s=100)

## tSNE plot by cell type
results2["tSNE1"] = X_embedded[:,0]
results2["tSNE2"] = X_embedded[:,1]
plt.figure(figsize=(20,12))
g = sns.FacetGrid(results2, hue="Development", col="CellType", legend_out=True)
g = g.map(plt.scatter, "tSNE1", "tSNE2",  s=100).add_legend()
